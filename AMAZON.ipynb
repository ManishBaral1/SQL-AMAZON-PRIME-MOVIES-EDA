# %% [markdown]
# # SQL Syntax and Data Exploration using Amazon Dataset
#
# ### Here we show some of SQL syntax or queries using them in Amazon movies and TV shows Dataset. We use the queries to do data filtering, joints, unions, aggregate functions, temp tables, etc.

# %% [markdown]
# ### Importing different libraries ( these libraries comes with python3 environment)

# %%
import numpy as np # linear algebra
import pandas as pd 
import pandas as pd
import sqlite3

# %% [markdown]
# ### Data loading i.e. reading csv files

# %%
df_amazon = pd.read_csv('amazon.csv')

# %%
print('The columns of the Amazon data frame are :-  ',df_amazon.columns) #print data frames
# Out:
# The columns of the Amazon data frame are :-   Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %% [markdown]
# ### Importing **SQLALCHEMY** and creating a **SQLITE ENGINE**

# %%
from sqlalchemy import create_engine
engine = create_engine('sqlite://', echo=False)

# export the dataframe as a table 'playstore' to the sqlite engine
df_amazon.to_sql("amazon", con =engine)
# Out:
# 9668

# %%
sql='''

Select * from amazon
limit 5

''';
df_sql = pd.read_sql_query(sql,con=engine)
df_sql.head()
# Out:
#    index show_id   type                 title        director  \
# 0      0      s1  Movie   The Grand Seduction    Don McKellar
# 1      1      s2  Movie  Take Care Good Night    Girish Joshi
# 2      2      s3  Movie  Secrets of Deception     Josh Webber
# 3      3      s4  Movie    Pink: Staying True  Sonia Anderson
# 4      4      s5  Movie         Monster Maker    Giles Foster
#
#                                                 cast         country  \
# 0     Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          Canada
# 1   Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar           India
# 2  Tom Sizemore, Lorenzo Lamas, Robert LaSardo, R...   United States
# 3  Interviews with: Pink, Adele, Beyoncé, Britney...   United States
# 4  Harry Dean Stanton, Kieran O'Brien, George Cos...  United Kingdom
#
#        date_added  release_year rating duration                listed_in  \
# 0  March 30, 2021          2014   None  113 min            Comedy, Drama
# 1  March 30, 2021          2018    13+  110 min     Drama, International
# 2  March 30, 2021          2017   None   74 min  Action, Drama, Suspense
# 3  March 30, 2021          2014   None   69 min              Documentary
# 4  March 30, 2021          1989   None   45 min           Drama, Fantasy
#
#                                          description
# 0  A small fishing village must procure a local d...
# 1  A Metro Family decides to fight a Cyber Crimin...
# 2  After a man discovers his wife is cheating on ...
# 3  Pink breaks the mold once again, bringing her ...
# 4  Teenage Matt Banting wants to work with a famo...

# %% [markdown]
# ### 1.Select *

# %%
sql='''
Select * from amazon
''';
df_sql = pd.read_sql_query(sql,con=engine)
df_sql.head()
# Out:
#    index show_id   type                 title        director  \
# 0      0      s1  Movie   The Grand Seduction    Don McKellar
# 1      1      s2  Movie  Take Care Good Night    Girish Joshi
# 2      2      s3  Movie  Secrets of Deception     Josh Webber
# 3      3      s4  Movie    Pink: Staying True  Sonia Anderson
# 4      4      s5  Movie         Monster Maker    Giles Foster
#
#                                                 cast         country  \
# 0     Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          Canada
# 1   Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar           India
# 2  Tom Sizemore, Lorenzo Lamas, Robert LaSardo, R...   United States
# 3  Interviews with: Pink, Adele, Beyoncé, Britney...   United States
# 4  Harry Dean Stanton, Kieran O'Brien, George Cos...  United Kingdom
#
#        date_added  release_year rating duration                listed_in  \
# 0  March 30, 2021          2014   None  113 min            Comedy, Drama
# 1  March 30, 2021          2018    13+  110 min     Drama, International
# 2  March 30, 2021          2017   None   74 min  Action, Drama, Suspense
# 3  March 30, 2021          2014   None   69 min              Documentary
# 4  March 30, 2021          1989   None   45 min           Drama, Fantasy
#
#                                          description
# 0  A small fishing village must procure a local d...
# 1  A Metro Family decides to fight a Cyber Crimin...
# 2  After a man discovers his wife is cheating on ...
# 3  Pink breaks the mold once again, bringing her ...
# 4  Teenage Matt Banting wants to work with a famo...

# %% [markdown]
# ### 2. Select distinct

# %%
sql='''
Select distinct(show_id) from amazon
''';
df_sql = pd.read_sql_query(sql,con=engine)
df_sql.head()
# Out:
#   show_id
# 0      s1
# 1      s2
# 2      s3
# 3      s4
# 4      s5

# %% [markdown]
# ### 3.Select where

# %%
sql='''
Select 
distinct(title) from amazon
where release_year >2020
''';
df_sql = pd.read_sql_query(sql,con=engine)
df_sql.head()
# Out:
#                                           title
# 0                                      Wildlike
# 1                                   White Tiger
# 2  WGC-Dell Technologies Match Play Reveal Show
# 3                                  War of Likes
# 4                       V1 Murder Case (Telugu)

# %% [markdown]
# ### 4. Select and, or , not

# %%
sql='''
Select 
distinct(title) from amazon
where release_year > 2020 and title='Monster Maker' or release_year < 2020 and title='The Grand Seduction'and not country= 'India'
''';
df_sql = pd.read_sql_query(sql,con=engine)
df_sql.head()
# Out:
#                  title
# 0  The Grand Seduction

# %% [markdown]
# ### 5. order by

# %%
sql='''
Select 
distinct(title) as name from amazon
order by title 
''';
df_sql = pd.read_sql_query(sql,con=engine)
df_sql.head()
# Out:
#                     name
# 0             "Mixed Up"
# 1  "The Paramedic Angel"
# 2                  #Home
# 3         #Home (4K UHD)
# 4              #IGotThis

# %% [markdown]
# ### 6. limit values

# %%
sql='''
Select * from amazon
limit 5
''';
df_sql = pd.read_sql_query(sql,con=engine)
df_sql.head()
# Out:
#    index show_id   type                 title        director  \
# 0      0      s1  Movie   The Grand Seduction    Don McKellar
# 1      1      s2  Movie  Take Care Good Night    Girish Joshi
# 2      2      s3  Movie  Secrets of Deception     Josh Webber
# 3      3      s4  Movie    Pink: Staying True  Sonia Anderson
# 4      4      s5  Movie         Monster Maker    Giles Foster
#
#                                                 cast         country  \
# 0     Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          Canada
# 1   Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar           India
# 2  Tom Sizemore, Lorenzo Lamas, Robert LaSardo, R...   United States
# 3  Interviews with: Pink, Adele, Beyoncé, Britney...   United States
# 4  Harry Dean Stanton, Kieran O'Brien, George Cos...  United Kingdom
#
#        date_added  release_year rating duration                listed_in  \
# 0  March 30, 2021          2014   None  113 min            Comedy, Drama
# 1  March 30, 2021          2018    13+  110 min     Drama, International
# 2  March 30, 2021          2017   None   74 min  Action, Drama, Suspense
# 3  March 30, 2021          2014   None   69 min              Documentary
# 4  March 30, 2021          1989   None   45 min           Drama, Fantasy
#
#                                          description
# 0  A small fishing village must procure a local d...
# 1  A Metro Family decides to fight a Cyber Crimin...
# 2  After a man discovers his wife is cheating on ...
# 3  Pink breaks the mold once again, bringing her ...
# 4  Teenage Matt Banting wants to work with a famo...

# %% [markdown]
# ### 7. Min, Max, count, avg, sum

# %%
sql='''
Select
min(release_year) as min_release_year,
max(release_year) as max_release_year,
count(distinct release_year) as count_of_release_year,
round(avg(release_year),2) as avg_of_all_release_years,
sum(release_year) as avg_of_all_release_years
from amazon
limit 1
''';
df_sql = pd.read_sql_query(sql,con=engine)
df_sql.head()
# Out:
#    min_release_year  max_release_year  count_of_release_year  \
# 0              1920              2021                    100
#
#    avg_of_all_release_years  avg_of_all_release_years
# 0                   2008.34                  19416649

# %% [markdown]
# ### 8. like

# %%
sql='''
Select distinct ' country that End with ia :- '|| country as Value from amazon
where country like"%ia"
union all
Select distinct 'country that Starts with ia :- '|| country as Value from amazon
where country like"ia%"
union all
Select distinct 'country that has ia :- '|| country as Value from amazon
where country like "%ia%"
union all
Select distinct 'country that starts and ends with a :- '|| country as Value from amazon
where country like "a%a%"
''';
df_sql = pd.read_sql_query(sql,con=engine)
df_sql.head()
# Out:
#                                                Value
# 0                  country that End with ia :- India
# 1   country that End with ia :- United States, India
# 2   country that End with ia :- United Kingdom, U...
# 3   country that End with ia :- United Kingdom, I...
# 4   country that End with ia :- Brazil, United St...

# %% [markdown]
# ### 9. in

# %%
sql='''
select * from amazon
where country in ('India','United States','Austrailia')
order by country asc
''';
df_sql = pd.read_sql_query(sql,con=engine)
df_sql.head()
# Out:
#    index show_id   type                 title         director  \
# 0      1      s2  Movie  Take Care Good Night     Girish Joshi
# 1    107    s108  Movie                Whoop!     Kreeti Gogia
# 2    142    s143  Movie   Wedding Cha Shinema  Saleel Kulkarni
# 3    178    s179  Movie              Viswasam             Siva
# 4    180    s181  Movie                 Virus       Aashiq Abu
#
#                                                 cast country      date_added  \
# 0   Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar   India  March 30, 2021
# 1                                       Abish Mathew   India            None
# 2  Shivraj Waichal, Rucha Inamdar, Mukta Barve, P...   India            None
# 3                            Ajith Kumar, Nayanthara   India            None
# 4        Revathy, Kunchako Boban, Parvathy Thiruvoth   India            None
#
#    release_year rating duration                         listed_in  \
# 0          2018    13+  110 min              Drama, International
# 1          2018    18+   64 min  Arts, Entertainment, and Culture
# 2          2019    ALL  138 min             Comedy, International
# 3          2019    13+  151 min      Action, Drama, International
# 4          2019    ALL  149 min  Drama, Science Fiction, Suspense
#
#                                          description
# 0  A Metro Family decides to fight a Cyber Crimin...
# 1  Abish Mathew is the world's greatest stand-up ...
# 2  An aspiring filmmaker reluctantly takes up the...
# 3  A village ruffian, who settles disputes in his...
# 4  Virus is a fiction based on true events, revol...

# %% [markdown]
# ### 10. between

# %%
sql='''
select * from amazon
where release_year between 2020 and 2021
''';
df_sql = pd.read_sql_query(sql,con=engine)
df_sql.head()
# Out:
#    index show_id     type                          title       director  \
# 0     13     s14    Movie                     Resilencia  Jep Barcelona
# 1     18     s19  TV Show  Zoë Coombs Marr: Bossy Bottom           None
# 2     21     s22  TV Show      Zo Zo Zombie: Mini-Series           None
# 3     23     s24  TV Show                   ZeroZeroZero           None
# 4     26     s27  TV Show             Zahara: The Return           None
#
#                                                 cast country      date_added  \
# 0  Rafinha Alcantara, Marc-André Ter Stegen, Serg...   Spain  April 24, 2021
# 1                                    Zoë Coombs Marr    None            None
# 2  Alex Cazares, Ben Diskin, Cristina Vee, Erika ...    None            None
# 3  ANDREA RISEBOROUGH, HAROLD TORRES, CLAUDIA PIN...   Italy            None
# 4  Natasha Heschélle, Curtis Morgan, Hannah Scott...    None            None
#
#    release_year rating  duration                      listed_in  \
# 0          2020   None    46 min            Documentary, Sports
# 1          2020    18+  1 Season  Comedy, Talk Show and Variety
# 2          2020  TV-Y7  1 Season          Action, Anime, Comedy
# 3          2020    18+  1 Season                       TV Shows
# 4          2020    16+  1 Season                       TV Shows
#
#                                          description
# 0  The documentary follows the midfielder’s every...
# 1  Zoë Coombs Marr has been on hiatus. Sort of. F...
# 2  Zo Zo Zombie is our undead hero who, with his ...
# 3  ZeroZeroZero series follows the journey of a c...
# 4  The story explores the history of slavery and ...

# %% [markdown]
# ### 11. joins

# %%
sql='''
select
n1.show_id as Show_idtable1,
n2.type as Show_idTable2,
n2.title as Showtable2
from amazon n1
join amazon n2 on n1.show_id = n2.show_id
''';
df_sql = pd.read_sql_query(sql,con=engine)
df_sql.head()
# Out:
#   Show_idtable1 Show_idTable2            Showtable2
# 0            s1         Movie   The Grand Seduction
# 1            s2         Movie  Take Care Good Night
# 2            s3         Movie  Secrets of Deception
# 3            s4         Movie    Pink: Staying True
# 4            s5         Movie         Monster Maker

# %% [markdown]
# ### 12. unions

# %%
sql='''
select * from amazon where country='India'
union all
select * from amazon where country='United States'
''';
df_sql = pd.read_sql_query(sql,con=engine)
df_sql.head()
# Out:
#    index show_id   type                 title         director  \
# 0      1      s2  Movie  Take Care Good Night     Girish Joshi
# 1    107    s108  Movie                Whoop!     Kreeti Gogia
# 2    142    s143  Movie   Wedding Cha Shinema  Saleel Kulkarni
# 3    178    s179  Movie              Viswasam             Siva
# 4    180    s181  Movie                 Virus       Aashiq Abu
#
#                                                 cast country      date_added  \
# 0   Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar   India  March 30, 2021
# 1                                       Abish Mathew   India            None
# 2  Shivraj Waichal, Rucha Inamdar, Mukta Barve, P...   India            None
# 3                            Ajith Kumar, Nayanthara   India            None
# 4        Revathy, Kunchako Boban, Parvathy Thiruvoth   India            None
#
#    release_year rating duration                         listed_in  \
# 0          2018    13+  110 min              Drama, International
# 1          2018    18+   64 min  Arts, Entertainment, and Culture
# 2          2019    ALL  138 min             Comedy, International
# 3          2019    13+  151 min      Action, Drama, International
# 4          2019    ALL  149 min  Drama, Science Fiction, Suspense
#
#                                          description
# 0  A Metro Family decides to fight a Cyber Crimin...
# 1  Abish Mathew is the world's greatest stand-up ...
# 2  An aspiring filmmaker reluctantly takes up the...
# 3  A village ruffian, who settles disputes in his...
# 4  Virus is a fiction based on true events, revol...

# %% [markdown]
# ### 13. case statements

# %%
sql='''
select
sum(case when country='India' then 1 else 0 end) as Shows_in_India,
sum(case when country='United States' then 1 else 0 end) as Shows_in_United_States,
sum(case when country='South Africa' then 1 else 0 end) as Shows_in_South_Africa
from amazon
''';
df_sql = pd.read_sql_query(sql,con=engine)
df_sql.head()
# Out:
#    Shows_in_India  Shows_in_United_States  Shows_in_South_Africa
# 0             229                     253                      1

# %% [markdown]
# ### 14. Sub Queries

# %%
sql='''
select distinct(a.title) from (select * from amazon) a
''';
df_sql = pd.read_sql_query(sql,con=engine)
df_sql.head()
# Out:
#                   title
# 0   The Grand Seduction
# 1  Take Care Good Night
# 2  Secrets of Deception
# 3    Pink: Staying True
# 4         Monster Maker

# %% [markdown]
# ### 15. coalesce

# %%
sql='''
select coalesce(release_year,0) as first_non_zero_value from amazon
limit 1
''';
df_sql = pd.read_sql_query(sql,con=engine)
df_sql.head()
#Helps us to handle null values, it replaces the null values with the data we feed after the comma
#syntax coalesce(col1name,submit value to replace the null value)
# Out:
#    first_non_zero_value
# 0                  2014

# %% [markdown]
# ### 16. Convert

# %%
sql='''
select cast(release_year as float) as first_non_zero_value from amazon
''';
df_sql = pd.read_sql_query(sql,con=engine)
df_sql.head()
# Out:
#    first_non_zero_value
# 0                2014.0
# 1                2018.0
# 2                2017.0
# 3                2014.0
# 4                1989.0

# %% [markdown]
# ### 17. lag/lead

# %%
sql='''
select
title,
release_year,
case when release_year=lag(release_year) over (order by release_year asc) then 1 else 0 end as Back_to_Back
from amazon
order by release_year asc
''';
df_sql = pd.read_sql_query(sql,con=engine)
df_sql.head(100)
# Out:
#                                                 title  release_year  \
# 0                                    Within Our Gates          1920
# 1                                           Pollyanna          1920
# 2                                 Nomads Of The North          1920
# 3                                 Robin Hood (Silent)          1922
# 4                                  One Exciting Night          1922
# ..                                                ...           ...
# 95                                     Things To Come          1936
# 96                                     Reefer Madness          1936
# 97  The Speed Reporter 1936 Crime Drama Thriller F...          1936
# 98                              Revolt of the Zombies          1936
# 99                                       Western Gold          1937
#
#     Back_to_Back
# 0              0
# 1              1
# 2              1
# 3              0
# 4              1
# ..           ...
# 95             1
# 96             1
# 97             1
# 98             1
# 99             0
#
# [100 rows x 3 columns]

# %% [markdown]
# ### 18. Row Number

# %%
sql='''
select 
title,type,director,
ROW_NUMBER() OVER (ORDER BY
        title asc) as row_number
        from amazon
group by title
order by title asc
''';
df_sql = pd.read_sql_query(sql,con=engine)
df_sql.head(100)
# Out:
#                                                 title     type      director  \
# 0                                          "Mixed Up"    Movie  Nishi Chawla
# 1                               "The Paramedic Angel"  TV Show          None
# 2                                               #Home    Movie  Rojin Thomas
# 3                                      #Home (4K UHD)    Movie  Rojin Thomas
# 4                                           #IGotThis  TV Show          None
# ..                                                ...      ...           ...
# 95      15-Minute Plyometrics: Jump Jump! 5.0 Workout    Movie          None
# 96            15-Minute Strength & Sculpt 4.0 Workout    Movie          None
# 97  15-Minute Total Body Shred 9.0 Workout (with w...    Movie          None
# 98  15-Minute Total Body Tone-Up 8.0 Workout (with...    Movie          None
# 99  15-Minute Upper Body Chisel 9.0 Workout (with ...    Movie          None
#
#     row_number
# 0            1
# 1            2
# 2            3
# 3            4
# 4            5
# ..         ...
# 95          96
# 96          97
# 97          98
# 98          99
# 99         100
#
# [100 rows x 4 columns]

# %% [markdown]
# ### 19. Dense Rank

# %%
sql='''
select a.value from (
Select 
distinct ' country that End with ia :- '|| country as Value,
DENSE_RANK() OVER (ORDER BY country asc) as rank from amazon
where country like"%ia"
)a
where rank=1

union all

select a.value from (
Select 
distinct ' first country that starts with a :- '|| country as Value,
DENSE_RANK() OVER (ORDER BY country asc) as rank from amazon
where country like"a%"
)a
where rank=1

union all

select a.value from (
Select 
distinct ' country that has a and minimum length 4 :- '|| country as Value,
DENSE_RANK() OVER (ORDER BY country asc) as rank from amazon
where country like"a__%"
)a
where rank=1

''';
df_sql = pd.read_sql_query(sql,con=engine)
df_sql.head()
# Out:
#                                                Value
# 0              country that End with ia :- Australia
# 1   first country that starts with a :- Afghanist...
# 2   country that has a and minimum length 4 :- Af...

# %% [markdown]
# ### 20. with

# %%
sql='''
with b as (
select 
a.country,
a.count_of_shows,
row_number () over (order by a.count_of_shows desc) as rank 
from
(
select 
count(distinct title) as count_of_shows,
country
from amazon
group by country
) a
)
select country as country_most_shows from b
where  b.rank=1
 '''   
df_sql = pd.read_sql_query(sql,con=engine)
df_sql.head()
# Out:
#   country_most_shows
# 0               None

# %% [markdown]
# ### 21. Count of Movies and TV Shows by Country

# %%
sql='''
select country, count(*) as count from amazon group by country order by count desc;

 '''   
df_sql = pd.read_sql_query(sql,con=engine)
df_sql.head()
# Out:
#           country  count
# 0            None   8996
# 1   United States    253
# 2           India    229
# 3  United Kingdom     28
# 4          Canada     16

# %% [markdown]
# ### 22. Top 5 Directors with the Most Movies and TV Shows

# %%
sql='''
select director, count(*) as count from amazon group by director order by count desc limit 5;

 '''   
df_sql = pd.read_sql_query(sql,con=engine)
df_sql.head()
# Out:
#                 director  count
# 0                   None   2083
# 1            Mark Knight    113
# 2          Cannis Holder     61
# 3  Moonbug Entertainment     37
# 4            Jay Chapman     34

# %% [markdown]
# ### 23. Distribution of Ratings

# %%
sql='''
select rating, count(*) as count from amazon group by rating order by rating;

 '''   
df_sql = pd.read_sql_query(sql,con=engine)
df_sql.head()
# Out:
#   rating  count
# 0   None    337
# 1    13+   2117
# 2     16      1
# 3    16+   1547
# 4    18+   1243

# %% [markdown]
# ### 24. Count of Movies and TV Shows Released Each Year

# %%
sql='''
select release_year, count(*) as count from amazon group by release_year order by release_year;


 '''   
df_sql = pd.read_sql_query(sql,con=engine)
df_sql.head()
# Out:
#    release_year  count
# 0          1920      3
# 1          1922      2
# 2          1923      1
# 3          1924      1
# 4          1925      8

# %% [markdown]
# ### 25. List Genre

# %%
sql='''
select distinct listed_in from amazon;
'''   
df_sql = pd.read_sql_query(sql,con=engine)
df_sql.head()
# Out:
#                  listed_in
# 0            Comedy, Drama
# 1     Drama, International
# 2  Action, Drama, Suspense
# 3              Documentary
# 4           Drama, Fantasy

# %% [markdown]
# ### 26. Count Movies and TV Shows by Genre

# %%
sql='''
select listed_in, count(*) as count from amazon group by listed_in order by count desc;

 '''   
df_sql = pd.read_sql_query(sql,con=engine)
df_sql.head()
# Out:
#          listed_in  count
# 0            Drama    986
# 1           Comedy    536
# 2  Drama, Suspense    399
# 3    Comedy, Drama    377
# 4  Animation, Kids    356

# %% [markdown]
# ### 27. List the Titles Released in 2018

# %%
sql='''
select title from amazon where release_year = 2018;

 '''   
df_sql = pd.read_sql_query(sql,con=engine)
df_sql.head()
# Out:
#                                title
# 0               Take Care Good Night
# 1           The Night Eats The World
# 2  Elon Musk: The Real Life Iron Man
# 3                                Zoe
# 4                    Yu-Gi-Oh! ARC-V

# %% [markdown]
# ### 28.Find Titles with Duration Greater Than 100 Minutes

# %%
sql='''
select title, duration from amazon where duration > 100;

 '''   
df_sql = pd.read_sql_query(sql,con=engine)
df_sql.head()
# Out:
#                   title duration
# 0   The Grand Seduction  113 min
# 1  Take Care Good Night  110 min
# 2  Secrets of Deception   74 min
# 3    Pink: Staying True   69 min
# 4         Monster Maker   45 min

# %% [markdown]
# ### 29. Find Titles with "Love" in the Title

# %%
sql='''
select title from amazon where title like '%Love%';

 '''   
df_sql = pd.read_sql_query(sql,con=engine)
df_sql.head()
# Out:
#                              title
# 0                     Young Lovers
# 1  Young Love (at the Sun Factory)
# 2  Young Love (at Bowery Ballroom)
# 3  Wotakoi: Love is Hard for Otaku
# 4              Where Love Found Me

# %% [markdown]
# ### 30. Find Titles Directed by "David Fincher"

# %%
sql='''
select title from amazon where director = 'David Fincher';

 '''   
df_sql = pd.read_sql_query(sql,con=engine)
df_sql.head()
# Out:
#                              title
# 0  The Girl With The Dragon Tattoo
# 1               The Social Network

# %% [markdown]
# ### 31.Find Titles with Ratings Between 7 and 8

# %%
sql='''
select title, rating from amazon where rating between 7 and 8;

 '''   
df_sql = pd.read_sql_query(sql,con=engine)
df_sql.head()
# Out:
#                     title rating
# 0      Xiaolin Chronicles     7+
# 1       Wipeout Australia     7+
# 2              Wild North     7+
# 3  Wild Colombia Revealed     7+
# 4    Tudor Monastery Farm     7+

# %% [markdown]
# ### 32. Find the Most Common Release Year

# %%
sql='''
select release_year, count(*) as count from amazon group by release_year order by count desc limit 1;

 '''   
df_sql = pd.read_sql_query(sql,con=engine)
df_sql.head()
# Out:
#    release_year  count
# 0          2021   1442

# %% [markdown]
# ### 33. Find Titles Released in the Last 5 Years

# %%
sql='''
select title from amazon where release_year >= strftime('%Y', 'now') - 5;

 '''   
df_sql = pd.read_sql_query(sql,con=engine)
df_sql.head()
# Out:
#                            title
# 0                     Resilencia
# 1                     Summer '03
# 2  Zoë Coombs Marr: Bossy Bottom
# 3      Zo Zo Zombie: Mini-Series
# 4                   ZeroZeroZero
